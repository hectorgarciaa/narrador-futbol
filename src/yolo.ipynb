# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from ultralytics import YOLO
#
# File c:\Users\hecto\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\__init__.py:13
#      10 if not os.environ.get("OMP_NUM_THREADS"):
#      11     os.environ["OMP_NUM_THREADS"] = "1"  # default for reduced CPU utilization during training
# ---> 13 from ultralytics.utils import ASSETS, SETTINGS
#      14 from ultralytics.utils.checks import check_yolo as checks
#      15 from ultralytics.utils.downloads import download
#
# File c:\Users\hecto\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\utils\__init__.py:25
#      23 import cv2
#      24 import numpy as np
# ---> 25 import torch
#      27 from ultralytics import __version__
#      28 from ultralytics.utils.git import GitRepo
#
# ...

# %%
model = YOLO("yolov8n.pt")  # modelo preentrenado
results = model("partido.mp4", show=True)
