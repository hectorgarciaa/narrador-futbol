# %%
import pandas as pd

datos = pd.read_csv('common/tracking_metrics.csv').sort_values(by='mean_coverage', ascending=False)
datos = datos[(datos['median_coverage'] > 0.9) | (datos['mean_coverage'] > 0.8)]
datos = datos.drop(columns=['video_source',	'video_filename', 'video_path', 'tracks_json_path', 'summary_json_path', 'updated_at_utc'	])
datos.head(10)
# Out:
#            video_stem  n_tracks  num_tracks  mean_coverage  median_coverage  \
# 81   A1606b0e6_0 (50)        25          21       0.919810         0.961333
# 59   A1606b0e6_0 (30)        25          21       0.897587         0.948000
# 57   A1606b0e6_0 (29)        25          21       0.891284         0.955941
# 86   A1606b0e6_0 (55)        24          22       0.876259         0.964619
# 157  B1606b0e6_1 (50)        25          22       0.871030         0.941333
# 158  B1606b0e6_1 (51)        25          22       0.868061         0.938667
# 169  B1606b0e6_1 (61)        25          22       0.864061         0.930000
# 175  B1606b0e6_1 (67)        25          22       0.858303         0.979333
# 191  B1606b0e6_1 (81)        25          22       0.857212         0.913333
# 42   A1606b0e6_0 (15)        25          22       0.856303         0.956000
#
#      25_coverage  mean_fragments  median_fragments  mean_gap_len_mean  \
# ...
